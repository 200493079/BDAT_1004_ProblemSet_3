# %% [markdown]
# ### Question No_1:     Step 1 - 3

# %%
import pandas as pd

users = pd.read_table(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',sep="|")
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step:4 What is the mean age per occupation??

# %%
Average_Age_Occupation = users.groupby('occupation').age.mean()

# %%
Average_Age_Occupation
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
users['is_male'] = users.gender.apply(lambda x: True if x == 'M' else False)
users.is_male
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 938    False
# 939     True
# 940     True
# 941    False
# 942     True
# Name: is_male, Length: 943, dtype: bool

# %%
Male_ratio = users.groupby("occupation")["gender"].value_counts().sort_values(ascending=True)
Male_ratio
# Out:
# occupation     gender
# technician     F           1
# homemaker      M           1
# retired        F           1
# lawyer         F           2
# entertainment  F           2
# engineer       F           2
# executive      F           3
# scientist      F           3
# salesman       F           3
# none           F           4
#                M           5
# healthcare     M           5
# homemaker      F           6
# programmer     F           6
# doctor         M           7
# salesman       M           9
# lawyer         M          10
# marketing      F          10
# healthcare     F          11
# artist         F          13
# retired        M          13
# artist         M          15
# marketing      M          16
# entertainment  M          16
# writer         F          19
# librarian      M          22
# writer         M          26
# educator       F          26
# technician     M          26
# scientist      M          28
# librarian      F          29
# ...

# %% [markdown]
# ### Step: 6 For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').age.agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step: 7 For each combination of occupation and sex, calculate the mean age

# %%
users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step: 8 For each occupation present the percentage of women and men

# %% [markdown]
# ### Question No_2: Step 1 - 3

# %%
import pandas as pd
euro12 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv")
euro12.head(5)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# ### Step:4 Select only the Goal column

# %%
Goal = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', usecols=['Goals'])
Goal
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %% [markdown]
# ### Step:5 How many team participated in the Euro2012?

# %%
Number_of_teams = len(euro12['Team'])
print(f' Total {Number_of_teams} teams participated in the Euro2012.')
# Out:
#  Total 16 teams participated in the Euro2012.

# %% [markdown]
# ### Step:6 What is the number of columns in the dataset?

# %%
total_columns = len(euro12.axes[1])
print("Total number of columns in the dataset are", total_columns)
# Out:
# Total number of columns in the dataset are 35

# %% [markdown]
# ### Step:7 View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
Yellow_and_Red= pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', usecols = ['Team', 'Yellow Cards', 'Red Cards'])
discipline = pd.DataFrame(Yellow_and_Red)
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Step: 8 Sort the teams by Red Cards, then to Yellow Cards

# %%
yellow_team = discipline.sort_values(by = 'Yellow Cards')
red_team = discipline.sort_values(by = 'Red Cards')

print("Sort by Red Cards \n",red_team)
print("sort By Yellow Cards \n",yellow_team)
# Out:
# Sort by Red Cards
#                     Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 10             Portugal            12          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# sort By Yellow Cards
#                     Team  Yellow Cards  Red Cards
# ...

# %% [markdown]
# ### Step:9 Calculate the mean Yellow Cards given per Team

# %%
print("Yellow Cards mean per Team", discipline["Yellow Cards"].mean())
# Out:
# Yellow Cards mean per Team 7.4375

# %% [markdown]
# ### Step:10 Filter teams that scored more than 6 goals
# ### Step 11. Select the teams that start with G

# %%
goal_greater_6 = euro12[euro12["Goals"] >= 6] 
Teams_with_G = euro12[['Team','Goals']][euro12.Team.str[0]=='G']
Teams_with_G
# Out:
#       Team  Goals
# 5  Germany     10
# 6   Greece      5

# %% [markdown]
# ### Step:12 Select the first 7 columns

# %%
View_7_col = euro12.iloc[:,0:8]
View_7_col
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3

# %%
except_last_3= euro12.iloc[:,0:32]
except_last_3
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step: 14 Present only the Shooting Accuracy from England, Italy and Russia

# %%
shooting = euro12['Shooting Accuracy'][euro12.Team.str.contains('England|Italy|Russia',regex=True)]
shooting
# Out:
# 3     50.0%
# 7     43.0%
# 12    22.5%
# Name: Shooting Accuracy, dtype: object

# %% [markdown]
# ### Question_3 Step 1-2

# %%
import pandas as pd
import numpy as np


First = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))

print("series_one")
print(First,"\n\n")


Second = pd.Series(np.random.randint(1, high=4, size=100, dtype='l'))
print("series_two")
print(Second,"\n\n")

Three = pd.Series(np.random.randint(10000, high=30001, size=100, dtype='l'))

print("series_three")
print(Three,"\n\n")
# Out:
# series_one
# 0     3
# 1     2
# 2     1
# 3     4
# 4     1
#      ..
# 95    1
# 96    4
# 97    4
# 98    3
# 99    2
# Length: 100, dtype: int32
#
#
# series_two
# 0     1
# 1     1
# 2     2
# 3     3
# 4     1
#      ..
# 95    3
# 96    3
# 97    3
# 98    2
# 99    1
# Length: 100, dtype: int32
#
#
# series_three
# 0     22859
# 1     28809
# 2     18857
# 3     21325
# 4     19781
#       ...
# 95    28728
# 96    18672
# 97    19971
# 98    15148
# 99    13062
# Length: 100, dtype: int32

# %% [markdown]
# ### Step: 3 Create a DataFrame by joinning the Series by column

# %%
New_df = pd.concat([First, Second, Three], axis=1)
New_df.head()
# Out:
#    0  1      2
# 0  3  1  22859
# 1  2  1  28809
# 2  1  2  18857
# 3  4  3  21325
# 4  1  1  19781

# %% [markdown]
# ### Step: 4 Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
New_df.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
New_df.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      3       1            22859
# 1      2       1            28809
# 2      1       2            18857
# 3      4       3            21325
# 4      1       1            19781

# %% [markdown]
# ### Step: 5 Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
Values_of_FST = pd.concat([First, Second, Three], axis=0)

Values_of_FST = Values_of_FST.to_frame()
print(type(Values_of_FST))

Values_of_FST
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         0
# 0       3
# 1       2
# 2       1
# 3       4
# 4       1
# ..    ...
# 95  28728
# 96  18672
# 97  19971
# 98  15148
# 99  13062
#
# [300 rows x 1 columns]

# %% [markdown]
# ### Step:6 Ops it seems it is going only until index 99. Is it true?

# %%
len(Values_of_FST)
# Out:
# 300

# %% [markdown]
# ### Step:7 Reindex the DataFrame so it goes from 0 to 299

# %%
Values_of_FST.reset_index(drop=True, inplace=True)
Values_of_FST
# Out:
#          0
# 0        3
# 1        2
# 2        1
# 3        4
# 4        1
# ..     ...
# 295  28728
# 296  18672
# 297  19971
# 298  15148
# 299  13062
#
# [300 rows x 1 columns]

# %% [markdown]
# ### Question_4 Step 1 - 3

# %%
import pandas as pd
import datetime

# %%
Wind = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'
data = pd.read_csv(Wind, sep = "\s+", parse_dates = [[0,1,2]]) 
data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# ### Step: 4 Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
# function Year_2061 
def Year_2061(x):
  year = x.year - 100 if x.year > 1989 else x.year
  return datetime.date(year, x.month, x.day)

# apply the function Year_2061 
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(Year_2061)

data.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# ### Step 5: Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data["Yr_Mo_Dy"] = pd.to_datetime(data["Yr_Mo_Dy"])

# set 'Yr_Mo_Dy' as the index
data = data.set_index('Yr_Mo_Dy')

data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.

# %%
data.sum().sum() / data.notna().sum().sum()
# Out:
# 10.227883764282181

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day

# %%
# dataframe
day_stats = pd.DataFrame()

day_stats['min'] = data.min(axis = 1) # min
day_stats['max'] = data.max(axis = 1) # max 
day_stats['mean'] = data.mean(axis = 1) # mean
day_stats['std'] = data.std(axis = 1) # std

day_stats.head()
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# ### Step 11: Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.

# %%
data.head(2)
data.loc[data.index.month == 1].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12: Downsample the record to a yearly frequency for each location

# %%
data.groupby(data.index.to_period('A')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966      13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967      12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968      11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969      11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970      12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971      11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# 1972      12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# ...

# %% [markdown]
# ### Step 13: Downsample the record to a monthly frequency for each location.

# %%
data.groupby(data.index.to_period('M')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03   10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10    9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11   16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12   16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data.groupby(data.index.to_period('W')).mean()
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# Yr_Mo_Dy
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667
# 1961-01-23/1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %% [markdown]
# ### Step 15: Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks

# %%
Weekly = data.resample('W').agg(['min','max','mean','std'])

Weekly.loc[Weekly.index[1:53], "RPT":"MAL"] .head(10)
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
#
#                         ROS         ...        CLO              BEL         \
# ...

# %% [markdown]
# ### Question No.5  Step 1 - 4

# %%
import pandas as pd

data_url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
chipo = pd.read_csv(data_url, sep = '\t')
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5-6: What is the number of observations and columns?

# %%
chipo.shape[0]
# Out:
# 4622

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7 - 8: Print the name of all the columns and index.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9 - 10  Which was the most-ordered item?/ For the most-ordered item, how many items were ordered?

# %%
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
chipo.item_name.unique().shape[0]
# Out:
# 50

# %% [markdown]
# ### Step 11: What was the most ordered item in the choice_description column?

# %%
chipo.choice_description.value_counts().head()
# Out:
# [Diet Coke]                                                                          134
# [Coke]                                                                               123
# [Sprite]                                                                              77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]     40
# Name: choice_description, dtype: int64

# %% [markdown]
# ### Step 12: How many items were orderd in total?

# %%
chipo.quantity.sum()
# Out:
# 4972

# %% [markdown]
# ### Step 13:
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type

# %%
df = pd.DataFrame(chipo)
print(df.dtypes)
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
df['item_price'] = pd.to_numeric(df['item_price'],errors = 'coerce')

print(df.dtypes)
# Out:
# order_id              float64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %% [markdown]
# ### Step 14 - 15 How much was the revenue for the period in the dataset/ How many orders were made in the period?

# %%
Rev=chipo['item_price'].sum()
print("The revenue for period $"+str(revenue))
order_count=chipo.groupby(['order_id'])
print("Number of Orders for period  "+str(len(order_count)))
# Out:
# The revenue for period $34500.16
# Number of Orders for period  1834

# %% [markdown]
# ### Step 16: What is the average revenue amount per order?

# %%
Sum_odr=chipo.groupby(['order_id'])['item_price'].sum()
Avg_odr=Sum_odr.mean()

print("Average revenue amount per order is $"+str(Avg_odr))
# Out:
# Average revenue amount per order is $18.81142857142869

# %% [markdown]
# ### Step: 17 How many different items are sold?

# %%
num_items =chipo.groupby(['item_name']).count()
print("There are "+str(len(num_items))+" different items sold")
# Out:
# There are 50 different items sold

# %% [markdown]
# ### Question 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
US_marriage_divorce = pd.read_csv('us-marriages-divorces-1867-2014.csv')
years = US_marriage_divorce['Year'].values
marriages_per_capita = US_marriage_divorce['Marriages_per_1000'].values
divorces_per_capita = US_marriage_divorce['Divorces_per_1000'].values

plt.plot(years, marriages_per_capita, label='marriages_per_capita')

plt.plot(years, divorces_per_capita, label='divorces_per_capita')

plt.title('Marriages_per_capita Vs divorces_per_capita')
plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.legend()
plt.show()

# %% [markdown]
# ### Question_7

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

# %%
divorce_data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
divorce_data = divorce_data[
    divorce_data['Year'].apply(lambda x: x in [1900, 1950, 2000])]

years = divorce_data['Year'].values
marriages_per_capita = divorce_data['Marriages_per_1000'].values
divorces_per_capita = divorce_data['Divorces_per_1000'].values

df = pd.DataFrame({'Per Capita Marriages': marriages_per_capita,
                   'Per Capita Divorce': divorces_per_capita}, index=years)
ax = df.plot.bar(rot=0)
# Out:
# <img src="data:image/png;base64,..." width="582.9630041449515">

# %% [markdown]
# ### Question 8

# %%
import pandas as pd
import matplotlib.pyplot as plt

actor = pd.read_csv('actor_kill_counts.csv')

actor_names = actor['Actor'].values
kill_counts = actor['Count'].values

# %%
df = pd.DataFrame({'Actors_Name': actor_names,
                   'Kill_Counts': kill_counts},index=actor_names)
ax = df.plot.barh()
# Out:
# <img src="data:image/png;base64,..." width="582.9630041449515">

# %% [markdown]
# ### Question 9 :

# %%
import pandas as pd

Roman_emperors = pd.read_csv('roman-emperor-reigns.csv')
Assassinated = Roman_emperors[
    Roman_emperors['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]

Count_of_assassinated = len(Assassinated)
Nornal_Deaths = len(Roman_emperors) - Count_of_assassinated

# %%
Count_of_assassinated
# Out:
# 30

# %%
Nornal_Deaths
# Out:
# 38

# %%
df = pd.DataFrame({'Count_of_assassinated': Count_of_assassinated,
                   'Nornal_Deaths': Nornal_Deaths},index=['Count_of_assassinated', 'Nornal_Deaths'])

# %%
plot = df.plot.pie(subplots=True,figsize=(8, 4))
# Out:
# <img src="data:image/png;base64,..." width="575.555596214266">

# %% [markdown]
# ### Question 10

# %%
import pandas as pd

Arcade_revenue_data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')

Revenue = Arcade_revenue_data['Total Arcade Revenue (billions)'].values
CS_Dr_awarded = Arcade_revenue_data[
    'Computer Science Doctorates Awarded (US)'].values

# %%
Revenue
# Out:
# array([1.196, 1.176, 1.269, 1.24 , 1.307, 1.435, 1.601, 1.654, 1.803,
#        1.734])

# %%
CS_Dr_awarded
# Out:
# array([ 861,  830,  809,  867,  948, 1129, 1453, 1656, 1787, 1611],
#       dtype=int64)

# %%
#create DataFrame
df = pd.DataFrame({'Revenue': Revenue,
                   'CS_Dr_awarded': CS_Dr_awarded})

#create scatterplot
df.plot.scatter(x='Revenue', y='CS_Dr_awarded',s=52, c='Blue')
# Out:
# <img src="data:image/png;base64,..." width="582.9630041449515">
# <AxesSubplot:xlabel='Revenue', ylabel='CS_Dr_awarded'>
